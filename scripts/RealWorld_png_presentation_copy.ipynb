# %%
import sqlite3
import enum
from functools import total_ordering

FIG_PATH = "/home/tim/Projects/bachelor-thesis/figs/"
DB_PATH = "/home/tim/idintfw.db"

con = sqlite3.connect(DB_PATH)
c = con.cursor()
rows = c.execute("SELECT * FROM Runs LEFT JOIN Errors ON Runs.ID=Errors.Run")

class App:
    def __init__(self, name, sources, sinks, classes, methods, statements, cgsize):
        self.name = name
        self.sources = sources
        self.sinks = sinks
        self.classes=classes
        self.methods=methods
        self.statements=statements
        self.cgsize=cgsize
        self.runs = []
        self.runsSMP = []
        self.fwRuns = []
        self.bwRuns = []
        self.fwsmpRuns = []
        self.bwsmpRuns = []
        
    def addRun(self, run):
        if run.direction == Direction.Forwards:
            self.fwRuns.append(run)
        elif run.direction == Direction.Backwards:
            self.bwRuns.append(run)
        elif run.direction == Direction.ForwardsSMP:
            self.fwsmpRuns.append(run)
        elif run.direction == Direction.BackwardsSMP:
            self.bwsmpRuns.append(run)
    
    def isTimeValid(self):
        return len(self.runs) == 2
    def isMemValid(self):
        return len(self.runsSMP) == 2
            
    def timeMedian(self, src, dst):
        if 0 < len(src) < 3:
            print("ERROR: Only %s time-runs for %s!" % (len(src), self.name))

        if len(src) != 3:
            return
        
        src.sort()
        if src[1].dataflowTime != 0:
            relDiff = abs(src[0].dataflowTime - src[1].dataflowTime) / abs(src[1].dataflowTime)
            absDiff = src[1].dataflowTime-src[0].dataflowTime
            if relDiff > 0.5 and absDiff > 5:
                print("FML0 %s for %s" % (src[0].ID, src[0].runID))
            relDiff = (src[2].dataflowTime - src[1].dataflowTime) / abs(src[1].dataflowTime)
            absDiff = src[2].dataflowTime-src[1].dataflowTime
            if relDiff > 0.5 and absDiff > 5:
                print("FML2 %s for %s" % (src[2].ID, src[2].runID))
        dst.append(src[1])
        src.clear()
        
#     def memMedian(self, src, dest):
#         if 0 < len(src) < 3:
#             print("ERROR: Only %s mem-runs for %s!" % (len(src), self.name))

#         if len(src) != 3:
#             return
        
#         src.sort(key=lambda x: x.maxMemPrecise)
#         if src[1].maxMemPrecise != 0:
#             relDiff = abs(src[0].maxMemPrecise - src[1].maxMemPrecise) / abs(src[1].maxMemPrecise)
#             if relDiff > 0.75:
#                 print("MEMFML0 %s for %s" % (src[0].ID, src[0].runID))
#             relDiff = (src[2].maxMemPrecise - src[1].maxMemPrecise) / abs(src[1].maxMemPrecise)
#             if abs(relDiff) > 0.75:
#                 print("MEMFML2 %s for %s" % (src[2].ID, src[2].runID))
#         dest.append(src[1])
#         src.clear()
    
    def selectMedian(self):
        self.timeMedian(self.fwsmpRuns, self.runsSMP)
        self.timeMedian(self.bwsmpRuns, self.runsSMP)
        self.timeMedian(self.fwRuns, self.runs)
        self.timeMedian(self.bwRuns, self.runs)

class Direction(enum.Enum):
    Forwards = 0
    Backwards = 1
    ForwardsSMP = 2
    BackwardsSMP = 3
    
@total_ordering
class TimeRun:
    def __init__(self, ID, direction, maxMem, infoflowEdges, aliasEdges, timeElapsed, dataflowTime, 
                 leaks, terminationState, absCountInfoflow, absCountAlias, runID, avgMemInfo, avgMemAlias,
                 finalMemInfo, finalMemAlias):
        if direction == "FastSolverfw":
            self.direction = Direction.Forwards
        elif direction == "FastSolverbw":
            self.direction = Direction.Backwards
        elif direction == "FastSolverfw_smp":
            self.direction = Direction.ForwardsSMP
        elif direction == "FastSolverbw_smp":
            self.direction = Direction.BackwardsSMP
        else:
            print("ERROR: Unknown direction!")
        self.ID = ID
        self.maxMem = maxMem
        self.infoflowEdges = infoflowEdges
        self.aliasEdges = aliasEdges
        self.timeElapsed = timeElapsed
        self.dataflowTime = dataflowTime
        self.leaks = leaks
        self.absCountInfoflow = absCountInfoflow
        self.absCountAlias = absCountAlias
        self.memoryTimeout = terminationState == 2 
        self.timeTimeout = terminationState == 1 and dataflowTime > 590
        self.noTimeout = not self.memoryTimeout and not self.timeTimeout
        self.runID = runID
        self.avgMemInfo = avgMemInfo
        self.avgMemAlias = avgMemAlias
        self.avgMem = (self.avgMemInfo + self.avgMemAlias) / 2.0
        self.finalMemInfo = finalMemInfo
        self.finalMemAlias = finalMemAlias
        self.maxMemPrecise = self.finalMemInfo + self.finalMemAlias
        
    def __lt__(self, other):
        return self.dataflowTime < other.dataflowTime

        
apps = {}
for row in rows:
    name = row[1]
    
    if not name in apps:
        apps[name] = App(name, row[16], row[17], row[18], row[19], row[20], row[21])

    # no need to add Runs which
    # did not start
    # had no sinks, thus -1 time
    # with exception thrown
    if row[6] == None or row[6] == -1 or row[26] != None or row[10] == 0:
        continue
    # only verify source sink manager when analysis started
    app = apps[name]
    if row[16] != app.sources:
        # print("Sources differ for %s: %s to %s" % (name, app.sources, row[16]))
        continue
    if row[17] != app.sinks:
        # print("Sinks differ for %s: %s to %s" % (name, app.sinks, row[17]))
        continue

    # ignore run 0
    if row[25] > 0:
        app.addRun(TimeRun(row[0], row[2], row[7], row[22], row[23], row[5], row[6], row[14], 
                           row[15], row[12], row[13], row[25], row[8], row[9], row[10], row[11]))
    
for app in apps.values():
    app.selectMedian()

def runToColor(run):
    if run.memoryTimeout:
        return "#d62728"
    elif run.timeTimeout:
        return "#ff7f0e"
    else:
        return "#1f77b4"
    
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from pylatex.utils import escape_latex 

matplotlib.rcParams.update({
    "pgf.texsystem": "lualatex",
    "pgf.preamble": [
        r'\usepackage{amsmath}'
    ],
    'font.family': 'sans-serif',
    'font.sans-serif': ['Roboto'],
    'text.usetex': True,
    'pgf.rcfonts': False,
})
# Out:
# FML2 2674 for 3
# FML2 2120 for 3
# FML2 2321 for 1
# FML0 2328 for 1
# FML2 2013 for 2
# FML0 3096 for 3
# FML0 2790 for 3
# FML2 3082 for 1
# FML2 2805 for 3
# /usr/lib64/python3.9/_collections_abc.py:940: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
# Delta of each app

xfw = []
datafw = []
cfw = []
xbw = []
databw = []
cbw = []

delta = []
for name, app in apps.items():
    if not app.isTimeValid():
        continue
        
    leaks = -1
    d = 0
       
    r1 = None
    r2 = None
    for run in app.runs:
        if run.direction == Direction.Forwards:
            datafw.append(run.dataflowTime)
            xfw.append(escape_latex(name))
            cfw.append(runToColor(run))
            d -= run.dataflowTime
            r1 = run
        elif run.direction == Direction.Backwards:
            databw.append(run.dataflowTime)
            xbw.append(escape_latex(name))
            cbw.append(runToColor(run))
            d += run.dataflowTime
            r2 = run
#         if leaks == -1:
#             leaks = run.leaks
#         elif leaks != run.leaks:
#             print(f"Leaks differ for {name}: {leaks} vs {run.leaks}")
            
    if abs(d) > 399:
        rel = app.sources / app.sinks
        if d < 0:
            ed1 = round(r1.infoflowEdges / r2.infoflowEdges)
            ed2 = round(r1.aliasEdges / r2.aliasEdges)
        else:
            ed1 = round(r2.infoflowEdges / (1 if r1.infoflowEdges == 0 else r1.infoflowEdges))
            ed2 = round(r2.aliasEdges / (1 if r1.aliasEdges == 0 else r1.aliasEdges))
#         print(f"{name}: {d}s with {app.sources}:{app.sinks} and edge {ed1}:{ed2}")
    delta.append(d)
    if (abs(d) > 500):
        print(f"{np.sign(d)}: {name}")

        
print(sum(delta)/len(xfw))
print(len(xfw))

fig = plt.figure()
base = 50
rounded = int(base * np.ceil(np.abs(delta).max()/base))
plt.hist(delta, bins=np.arange(-rounded, rounded, base), edgecolor='black')
plt.xlabel("$\\Delta$ Data Flow Time")
plt.ylabel("Frequency")
plt.savefig(FIG_PATH + "deltaHist.png", dpi=300)

# fig = plt.figure(figsize=(20, 5))
# ax = fig.add_subplot(111)
# ind = np.arange(len(xfw))
# width = 0.2
# ax.bar(ind, delta, width)
# ax.bar(ind - width/2, datafw, width, color=cfw)
# ax.bar(ind + width/2, databw, width, color=cbw)
# ax.set_xticklabels(xfw)
# plt.xticks(ind)
# ax.set_ylabel("$\\Delta$ Dataflow Time")
# _ = plt.xticks(rotation=90)
# plt.savefig(FIG_PATH + "dataflowDelta.png", dpi=300)
# Out:
# -1: ru.beeline.services.apk
# -1: com.backgrounderaser.cutout.photoeditor.apk
# -1: com.microsoft.office.officehubrow.apk
# -1: com.autoscout24.apk
# -1: hr.palamida.apk
# -1: com.kinky.fetlifestyle.apk
# -1: com.apartmentlist.mobile.apk
# -1: com.grabtaxi.passenger.apk
# -1: com.murphy.driverewards.apk
# -1: com.rcmbusiness.apk
# -1: dbx.taiwantaxi.apk
# -1: com.socialnetwork.hookupsapp.apk
# -1: com.clusterdev.hindikeyboard.apk
# -1: document.scanner.scan.pdf.image.text.apk
# -1: app.habitaclia2.apk
# -1: com.opera.touch.apk
# -1: com.astepanov.mobile.mathforkids.apk
# -1: com.zoho.sheet.android.apk
# -1: au.com.auspost.android.apk
# -1: com.buildium.resident.android.apk
# 1: com.jrtstudio.music.apk
# -1: com.onlyoffice.documents.apk
# 1: com.cloudmosa.puffinFree.apk
# 1: com.spinmaster.enterprise.colleggtibles.apk
# -1: com.match.android.matchmobile.apk
# 1: com.uba.vericash.apk
# -1: com.musicplayer.music.apk
# -1: com.microsoft.office.onenote.apk
# -1: it.casa.app.apk
# -1: com.fuib.android.spot.online.apk
# 1: com.finlim.forkapp.apk
# -1: app.quiktrip.com.quiktrip.apk
# -1: com.sendo.apk
# -108.7089552238806
# 134

# %%
# Per Sources/Sinks
blue_dot = mlines.Line2D([], [], color='#1f77b4', marker='.', linestyle='None',
                          markersize=10, label='No Timeout')
orange_dot = mlines.Line2D([], [], color='#ff7f0e', marker='.', linestyle='None',
                          markersize=10, label='Time Timeout')
red_dot = mlines.Line2D([], [], color='#d62728', marker='.', linestyle='None',
                          markersize=10, label='Memory Timeout')
green_line = mlines.Line2D([], [], color='g',
                          markersize=10, label='Lin. Regression')
handles = [blue_dot, orange_dot, red_dot]
handles2 = [blue_dot, orange_dot, red_dot, green_line]

from scipy import stats
from sklearn.metrics import r2_score

xsources = []
xsinks = []
xratio = []
xstmts = []
xclasses = []
xmethods = []
xcg = []
xedgesfw = [[],[]]
xedgesbw = [[],[]]
xpropfw = []
xpropbw = []
datafw = []
cfw = []
databw = []
cbw = []
t1 = []
t2 = []
for name, app in apps.items():
    if not app.isTimeValid():
        continue
    for run in app.runs:
        if run.direction == Direction.Forwards:
            datafw.append(run.dataflowTime)
            xsources.append(app.sources)
            xsinks.append(app.sinks)
            xratio.append((app.sinks - app.sources))
            xstmts.append(app.statements)
            xclasses.append(app.classes)
            xmethods.append(app.methods)
            xcg.append(app.cgsize)
            xedgesfw[0].append(run.absCountInfoflow)
            xedgesfw[1].append(run.absCountAlias)
            cfw.append(runToColor(run))
            t1.append(run.memoryTimeout)
        elif run.direction == Direction.Backwards:
            databw.append(run.dataflowTime)
            cbw.append(runToColor(run))
            xedgesbw[0].append(run.absCountInfoflow)
            xedgesbw[1].append(run.absCountAlias)
            t2.append(run.memoryTimeout)

print(np.std(datafw))
print(np.std(databw))
            
from scipy.stats import ttest_ind
tt = ttest_ind(datafw, databw, equal_var=True)
print(tt)
# tt = ttest_ind(datafw2, databw2, equal_var=False)
# print(tt)
tt2 = ttest_ind(t1, t2, equal_var=True)
print(tt2)

plt.figure()
plt.scatter(xsources, datafw, c=cfw)
plt.xlabel("Number of Sources")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-sources.png", dpi=300)       
plt.figure()
plt.scatter(xsinks, datafw, c=cfw)
plt.xlabel("Number of Sinks")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-sinks.png", dpi=300)
plt.figure()
plt.scatter(xratio, np.subtract(databw, datafw))
plt.xlabel("Ratio of Sources to Sinks")
plt.ylabel("Data Flow Time (s)")
# plt.title("Forward")
# plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "dataflow-ssratio.png", dpi=300)       


plt.figure()
plt.scatter(xsources, databw, c=cbw)
plt.xlabel("Number of Sources")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-sources.png", dpi=300)
plt.figure()
plt.scatter(xsinks, databw, c=cbw)
plt.xlabel("Number of Sinks")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-sinks.png", dpi=300)
# plt.figure()
# plt.scatter(xratio, databw, c=cbw)
# plt.xlabel("Ratio of Sources to Sinks")
# plt.ylabel("Data Flow Time (s)")
# plt.title("Backward")
# plt.legend(handles=handles)
# plt.tight_layout()
# plt.savefig(FIG_PATH + "bw_dataflow-ssratio.png", dpi=300)

plt.figure()
plt.scatter(xstmts, datafw, c=cfw)
plt.xlabel("Statements")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-statements.png", dpi=300)
plt.figure()
plt.scatter(xmethods, datafw, c=cfw)
plt.xlabel("Methods")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-methods.png", dpi=300)
plt.figure()
plt.scatter(xclasses, datafw, c=cfw)
plt.xlabel("Classes")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-classes.png", dpi=300)
plt.figure()
plt.scatter(xcg, datafw, c=cfw)
plt.xlabel("Callgraph Size")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-cg.png", dpi=300)
plt.figure()
plt.scatter(xstmts, databw, c=cbw)
plt.xlabel("Statements")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-statements.png", dpi=300)
plt.figure()
plt.scatter(xmethods, databw, c=cbw)
plt.xlabel("Methods")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-methods.png", dpi=300)
plt.figure()
plt.scatter(xclasses, databw, c=cbw)
plt.xlabel("Classes")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-classes.png", dpi=300)
plt.figure()
plt.scatter(xcg, databw, c=cbw)
plt.xlabel("Callgraph Size")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-cg.png", dpi=300)

d = 4

edgeMax = max(np.max(np.add(xedgesfw[0], xedgesfw[1])), np.max(np.add(xedgesbw[0], xedgesbw[1])))
scale = np.arange(0, (round(edgeMax/10**7)+1) * 10**7, 10**7)
plt.figure()
x = np.add(xedgesfw[0], xedgesfw[1])
y = datafw
plt.scatter(x, y, c=cfw)
mymodel = np.poly1d(np.polyfit(x, y, d))
myline = np.linspace(np.min(x), np.max(x), 100)
# plt.plot(myline, mymodel(myline), 'g')

reg1x = []
reg1y = []
reg2x = []
reg2y = []
for (dx, dy, c) in zip(x, y, cfw):
    if c == "#1f77b4":
        reg1x.append(dx)
        reg1y.append(dy)
    else:
        reg2x.append(dx)
        reg2y.append(dy)
coef = np.polyfit(reg1x,reg1y,1)
regf = np.poly1d(coef) 
plt.plot(myline, regf(myline), 'g')
coef = np.polyfit(reg2x,reg2y,1)
regf = np.poly1d(coef)
plt.plot(myline, regf(myline), "g")

plt.xticks(scale)
plt.xlabel("Edge Count")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")

plt.legend(handles=handles2)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_dataflow-edges.png", dpi=300)
print(r2_score(y, mymodel(x)))
print("C " + str(np.corrcoef(x, y)[0,1]))
plt.figure()
x = np.add(xedgesbw[0], xedgesbw[1])
y = databw
plt.scatter(x, y, c=cbw)
mymodel = np.poly1d(np.polyfit(x, y, d))
myline = np.linspace(np.min(x), np.max(x), 100)
# plt.plot(myline, mymodel(myline), 'g')

reg1x = []
reg1y = []
reg2x = []
reg2y = []
for (dx, dy, c) in zip(x, y, cbw):
    if c == "#1f77b4":
        reg1x.append(dx)
        reg1y.append(dy)
    else:
        reg2x.append(dx)
        reg2y.append(dy)
coef = np.polyfit(reg1x,reg1y,1)
regf = np.poly1d(coef) 
plt.plot(myline, regf(myline), 'g')
coef = np.polyfit(reg2x,reg2y,1)
regf = np.poly1d(coef)
plt.plot(myline, regf(myline), "g")

plt.xticks(scale)
plt.xlabel("Edge Count")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")

plt.legend(handles=handles2)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-edges.png", dpi=300)
print(r2_score(y, mymodel(x)))
print("C " + str(np.corrcoef(x, y)[0,1]))

# edgeMax = max(np.max(xedgesfw[0]), np.max(xedgesbw[0]))
# scale = np.arange(0, (round(edgeMax/10**7)+1) * 10**7, 10**7)
plt.figure()
x = xedgesfw[0]
y = datafw
plt.scatter(x, y, c=cfw)
myline = np.linspace(np.min(x), np.max(x), 100)
mymodel = np.poly1d(np.polyfit(x, y, d))
plt.plot(myline, mymodel(myline), 'g')
plt.xticks(scale)
plt.xlabel("Infoflow Edge Count")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")

plt.legend(handles=handles2)
plt.tight_layout()
print(r2_score(y, mymodel(x)))
plt.savefig(FIG_PATH + "fw_dataflow-iedges.png", dpi=300)
scale = np.arange(0, (round(edgeMax/10**7)+1) * 10**7, 10**7)
plt.figure()
x = xedgesbw[0]
y = databw
plt.scatter(x, y, c=cbw)
mymodel = np.poly1d(np.polyfit(x, y, d))
myline = np.linspace(np.min(x), np.max(x), 100)
plt.plot(myline, mymodel(myline), 'g')
plt.xticks(scale)
plt.xlabel("Infoflow Edge Count")
plt.ylabel("Data Flow Time (s)")

plt.title("Backward")
plt.legend(handles=handles2)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-iedges.png", dpi=300)
print(r2_score(y, mymodel(x)))

# edgeMax = max(np.max(xedgesfw[1]), np.max(xedgesbw[1]))
# scale = np.arange(0, (round(edgeMax/10**7)+1) * 10**7, 10**7)
plt.figure()
x = xedgesfw[1]
y = datafw
plt.scatter(x, y, c=cfw)
mymodel = np.poly1d(np.polyfit(x, y, d))
myline = np.linspace(np.min(x), np.max(x), 100)
plt.plot(myline, mymodel(myline), 'g')
plt.xticks(scale)
plt.xlabel("Alias Edge Count")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.legend(handles=handles2)

plt.tight_layout()
print(r2_score(y, mymodel(x)))
plt.savefig(FIG_PATH + "fw_dataflow-aedges.png", dpi=300)
plt.figure()
x = xedgesbw[1]
y = databw
plt.scatter(x, y, c=cbw)
mymodel = np.poly1d(np.polyfit(x, y, d))
myline = np.linspace(np.min(x), np.max(x), 100)
plt.plot(myline, mymodel(myline), 'g')
plt.xticks(scale)
plt.xlabel("Alias Edge Count")
plt.ylabel("Data Flow Time (s)")

plt.title("Backward")
plt.legend(handles=handles2)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_dataflow-aedges.png", dpi=300)
print(r2_score(y, mymodel(x)))
# Out:
# 209.0570584743033
# 277.3725508535957
# Ttest_indResult(statistic=3.609481198095022, pvalue=0.00036652540186813445)
# Ttest_indResult(statistic=-1.421716074237286, pvalue=0.1562800915184206)
# 0.9302297906449848
# C 0.730991318105134
# 0.9757099053086192
# C 0.9333038991151535
# 0.9126358525587691
# 0.9347429156210513
# 0.9342413526890551
# 0.935111696706161

# %%
datafw = []
datafw2 = []
memfw = []
memfw2 = []
iabsfw = []
iabsfw2 = []
aabsfw = []
aabsfw2 = []
tofw = [0, 0, 0]

databw = []
databw2 = []
membw = []
membw2 = []
iabsbw = []
iabsbw2 = []
aabsbw = []
aabsbw2 = []
tobw = [0, 0, 0]

for name, app in apps.items():
    if not app.isTimeValid:
        continue
    
    for run in app.runs:
        if run.direction == Direction.Forwards:
            datafw.append(run.dataflowTime)
            memfw.append(run.maxMem)
            iabsfw.append(run.absCountInfoflow)
            aabsfw.append(run.absCountAlias)
            if run.memoryTimeout:
                tofw[2] += 1
            elif run.timeTimeout:
                tofw[1] += 1
            else:
                tofw[0] += 1
                datafw2.append(run.dataflowTime)
                memfw2.append(run.maxMem)
                iabsfw2.append(run.absCountInfoflow)
                aabsfw2.append(run.absCountAlias)
        elif run.direction == Direction.Backwards:
            databw.append(run.dataflowTime)
            membw.append(run.maxMem)
            iabsbw.append(run.absCountInfoflow)
            aabsbw.append(run.absCountAlias)
            if run.memoryTimeout:
                tobw[2] += 1
            elif run.timeTimeout:
                tobw[1] += 1
            else:
                tobw[0] += 1
                databw2.append(run.dataflowTime)
                membw2.append(run.maxMem)
                iabsbw2.append(run.absCountInfoflow)
                aabsbw2.append(run.absCountAlias)
#                 if run.dataflowTime == 0:
#                     print(name)
                
# print(f"DFlow/Abs {sum(datafw) / (sum(iabsfw)+sum(aabsfw)):.2f} & {sum(databw) / (sum(iabsbw2)+sum(aabsbw)):.2f}")
            
percentile = 85
print("WITH TIMEOUTS")
print(f"Data Flow Time & ${round(sum(datafw) / sum(tofw),2):.2f}s$ & ${np.median(datafw):.2f}s$ & ${round(np.percentile(datafw, percentile), 2):.2f}s$\\\\")
print("\\hline")
print(f"Edge Propagations Infoflow & ${round(np.average(iabsfw), 2):.2f}$ & ${round(np.median(iabsfw), 2):.2f}$ & ${round(np.percentile(iabsfw, percentile), 2):.2f}$\\\\")
print(f"Edge Propagations Alias & ${round(np.average(aabsfw), 2):.2f}$ & ${round(np.median(aabsfw), 2):.2f}$ & ${round(np.percentile(aabsfw, percentile), 2):.2f}$\\\\")
print(f"Total Edge Propagations & ${round(np.average(np.add(iabsfw, aabsfw)), 2):.2f}$ & ${round(np.median(np.add(iabsfw, aabsfw)), 2):.2f}$ & ${round(np.percentile(np.add(iabsfw, aabsfw), percentile), 2):.2f}$\\\\")
print("\\hline")
print(f"Memory Timeouts & \multicolumn{{3}}{{r}}{{${round((tofw[2] / sum(tofw) * 100), 2):.2f}\\%$}}\\\\")
print(f"Time Timeouts & \multicolumn{{3}}{{r}}{{${round((tofw[1] / sum(tofw) * 100), 2):.2f}\\%$}}\\\\")
print()
print(f"Data Flow Time & ${round(sum(databw) / sum(tobw),2):.2f}s$ & ${np.median(databw):.2f}s$ & ${round(np.percentile(databw, percentile), 2):.2f}s$\\\\")
print("\\hline")
print(f"Edge Propagations Infoflow & ${round(np.average(iabsbw), 2):.2f}$ & ${round(np.median(iabsbw), 2):.2f}$ & ${round(np.percentile(iabsbw, percentile), 2):.2f}$\\\\")
print(f"Edge Propagations Alias & ${round(np.average(aabsbw), 2):.2f}$ & ${round(np.median(aabsbw), 2):.2f}$ & ${round(np.percentile(aabsbw, percentile), 2):.2f}$\\\\")
print(f"Total Edge Propagations & ${round(np.average(np.add(iabsbw, aabsbw)), 2):.2f}$ & ${round(np.median(np.add(iabsbw, aabsbw)), 2):.2f}$ & ${round(np.percentile(np.add(iabsbw, aabsbw), percentile), 2):.2f}$\\\\")
print("\\hline")
print(f"Memory Timeouts & \multicolumn{{3}}{{r}}{{${round((tobw[2] / sum(tobw) * 100), 2):.2f}\\%$}}\\\\")
print(f"Time Timeouts & \multicolumn{{3}}{{r}}{{${round((tobw[1] / sum(tobw) * 100), 2):.2f}\\%$}}\\\\")

print()
print()

print("AND WITHOUT")
print(f"Data Flow Time & ${round(np.average(datafw2),2):.2f}s$ & ${np.median(datafw2):.2f}s$ & ${round(np.percentile(datafw2, percentile), 2):.2f}s$\\\\")
print("\\hline")
print(f"Edge Propagations Infoflow & ${round(np.average(iabsfw2), 2):.2f}$ & ${round(np.median(iabsfw2), 2):.2f}$ & ${round(np.percentile(iabsfw2, percentile), 2):.2f}$\\\\")
print(f"Edge Propagations Alias & ${round(np.average(aabsfw2), 2):.2f}$ & ${round(np.median(aabsfw2), 2):.2f}$ & ${round(np.percentile(aabsfw2, percentile), 2):.2f}$\\\\")
print(f"Total Edge Propagations & ${round(np.average(np.add(iabsfw2, aabsfw2)), 2):.2f}$ & ${round(np.median(np.add(iabsfw2, aabsfw2)), 2):.2f}$ & ${round(np.percentile(np.add(iabsfw2, aabsfw2), percentile), 2):.2f}$\\\\")
print()
print(f"Data Flow Time & ${round(np.average(databw2),2):.2f}s$ & ${np.median(databw2):.2f}s$ & ${round(np.percentile(databw2, percentile), 2):.2f}s$\\\\")
print("\\hline")
print(f"Edge Propagations Infoflow & ${round(np.average(iabsbw2), 2):.2f}$ & ${round(np.median(iabsbw2), 2):.2f}$ & ${round(np.percentile(iabsbw2, percentile), 2):.2f}$\\\\")
print(f"Edge Propagations Alias & ${round(np.average(aabsbw2), 2):.2f}$ & ${round(np.median(aabsbw2), 2):.2f}$ & ${round(np.percentile(aabsbw2, percentile), 2):.2f}$\\\\")
print(f"Total Edge Propagations & ${round(np.average(np.add(iabsbw2, aabsbw2)), 2):.2f}$ & ${round(np.median(np.add(iabsbw2, aabsbw2)), 2):.2f}$ & ${round(np.percentile(np.add(iabsbw2, aabsbw2), percentile), 2):.2f}$\\\\")

# print(f"Average Runtime & ${round(sum(datafw2) / tofw[0],2):.2f}s$ & ${round(sum(databw2) / tobw[0],2):.2f}s$\\\\")
# print(f"Median Runtime & ${np.median(datafw2):.2f}s$ & ${np.median(databw2):.2f}s$\\\\")
# print(f"{percentile}\\textsuperscript{{th}} Percentile & ${round(np.percentile(datafw2, percentile), 2):.2f}s$ & ${round(np.percentile(databw2, percentile), 2):.2f}s$\\\\")
# print("\\hline")
# print(f"Average Abstractions Infoflow & ${round(sum(iabsfw2)/sum(tofw)):.2f}$ & ${round(sum(iabsbw2)/sum(tobw)):.2f}$\\\\")
# print(f"Average Abstractions Alias & ${round(sum(aabsfw2)/sum(tofw)):.2f}$ & ${round(sum(aabsbw2)/sum(tobw)):.2f}$\\\\")
# print(f"Average Total Abstractions & ${round(sum(iabsfw2)/sum(tofw))+round(sum(aabsfw2)/sum(tofw)):.2f}$ & ${round(sum(iabsbw2)/sum(tobw))+round(sum(aabsbw2)/sum(tobw)):.2f}$\\\\")
# Out:
# WITH TIMEOUTS
# Data Flow Time & $518.93s$ & $600.00s$ & $605.10s$\\
# \hline
# Edge Propagations Infoflow & $34555326.97$ & $41743088.00$ & $52163969.60$\\
# Edge Propagations Alias & $12562479.07$ & $14598571.50$ & $18638900.10$\\
# Total Edge Propagations & $47117806.04$ & $57697027.00$ & $70602469.30$\\
# \hline
# Memory Timeouts & \multicolumn{3}{r}{$2.99\%$}\\
# Time Timeouts & \multicolumn{3}{r}{$80.60\%$}\\
#
# Data Flow Time & $413.19s$ & $600.00s$ & $606.00s$\\
# \hline
# Edge Propagations Infoflow & $13826566.90$ & $14981108.50$ & $23712802.00$\\
# Edge Propagations Alias & $33567561.46$ & $43444060.00$ & $56773141.00$\\
# Total Edge Propagations & $47394128.36$ & $60855935.50$ & $79405729.00$\\
# \hline
# Memory Timeouts & \multicolumn{3}{r}{$6.62\%$}\\
# Time Timeouts & \multicolumn{3}{r}{$59.56\%$}\\
#
#
# AND WITHOUT
# Data Flow Time & $76.91s$ & $0.00s$ & $108.05s$\\
# \hline
# Edge Propagations Infoflow & $5651572.23$ & $28692.00$ & $7164554.30$\\
# Edge Propagations Alias & $1864306.77$ & $8689.50$ & $4212872.40$\\
# Total Edge Propagations & $7515879.00$ & $37310.00$ & $11377426.70$\\
#
# Data Flow Time & $35.20s$ & $0.00s$ & $39.25s$\\
# \hline
# Edge Propagations Infoflow & $2353723.61$ & $19940.50$ & $1733519.75$\\
# Edge Propagations Alias & $3795159.13$ & $20013.50$ & $6883734.25$\\
# Total Edge Propagations & $6148882.74$ & $39954.00$ & $8692988.50$\\

# %%
# Per Sources/Sinks
blue_dot = mlines.Line2D([], [], color='#1f77b4', marker='.', linestyle='None',
                          markersize=10, label='No Timeout')
orange_dot = mlines.Line2D([], [], color='#ff7f0e', marker='.', linestyle='None',
                          markersize=10, label='Time Timeout')
red_dot = mlines.Line2D([], [], color='#d62728', marker='.', linestyle='None',
                          markersize=10, label='Memory Timeout')
handles = [blue_dot, orange_dot, red_dot]

xsources = []
xsinks = []
xstmts = []
xratio = []
xclasses = []
xmethods = []
xcg = []
xedgesfw = []
xedgesbw = []
datafw = []
cfw = []
databw = []
cbw = []
for name, app in apps.items():
    if not app.isMemValid():
        continue
        
    for run in app.runsSMP:
        if run.direction == Direction.ForwardsSMP:
            datafw.append(run.maxMemPrecise)
            xsources.append(app.sources)
            xsinks.append(app.sinks)
            xstmts.append(app.statements)
            xratio.append((app.sinks - app.sources))
            xclasses.append(app.classes)
            xmethods.append(app.methods)
            xcg.append(app.cgsize)
            c = runToColor(run)
            cfw.append(runToColor(run))
            xedgesfw.append(run.absCountInfoflow + run.absCountAlias)
        elif run.direction == Direction.BackwardsSMP:
            databw.append(run.maxMemPrecise)
            cbw.append(runToColor(run))
            xedgesbw.append(run.absCountInfoflow + run.absCountAlias)


plt.figure()
plt.scatter(xsources, datafw, c=cfw)
plt.xlabel("Number of Sources")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-sources.png", dpi=300)       
plt.figure()
plt.scatter(xsinks, datafw, c=cfw)
plt.xlabel("Number of Sinks")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-sinks.png", dpi=300)
# plt.figure()
# plt.scatter(xratio, datafw, c=cfw)
# plt.xlabel("Ratio of Sources to Sinks")
# plt.ylabel("Maximum Memory Consumption (MB)")
# plt.title("Forward")
# plt.legend(handles=handles)
# plt.tight_layout()
# plt.savefig(FIG_PATH + "fw_maxmem-ssratio.png", dpi=300)

plt.figure()
plt.scatter(xsources, databw, c=cbw)
plt.xlabel("Number of Sources")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-sources.png", dpi=300)
plt.figure()
plt.scatter(xsinks, databw, c=cbw)
plt.xlabel("Number of Sinks")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-sinks.png", dpi=300)
plt.figure()
# plt.scatter(xratio, databw, c=cbw)
# plt.xlabel("Ratio of Sources to Sinks")
# plt.ylabel("Maximum Memory Consumption (MB)")
# plt.title("Backward")
# plt.legend(handles=handles)
# plt.tight_layout()
# plt.savefig(FIG_PATH + "bw_maxmem-ssratio.png", dpi=300)

plt.figure()
plt.scatter(xstmts, datafw, c=cfw)
plt.xlabel("Statements")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-statements.png", dpi=300)
plt.figure()
plt.scatter(xmethods, datafw, c=cfw)
plt.xlabel("Methods")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-methods.png", dpi=300)
plt.figure()
plt.scatter(xclasses, datafw, c=cfw)
plt.xlabel("Classes")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-classes.png", dpi=300)
plt.figure()
plt.scatter(xcg, datafw, c=cfw)
plt.xlabel("Callgraph Size")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-cg.png", dpi=300)
plt.figure()
plt.scatter(xstmts, databw, c=cbw)
plt.xlabel("Statements")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-statements.png", dpi=300)
plt.figure()
plt.scatter(xmethods, databw, c=cbw)
plt.xlabel("Methods")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-methods.png", dpi=300)
plt.figure()
plt.scatter(xclasses, databw, c=cbw)
plt.xlabel("Classes")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-classes.png", dpi=300)
plt.figure()
plt.scatter(xcg, databw, c=cbw)
plt.xlabel("Callgraph Size")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-cg.png", dpi=300)

edgeMax = np.max(xedgesbw)
scale = np.arange(0, (round(edgeMax/10**7)+1) * 10**7, 10**7)
plt.figure()
plt.scatter(xedgesfw, datafw, c=cfw)
plt.xticks(scale)
plt.xlabel("Edge Count")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "fw_maxmem-edges.png", dpi=300)

plt.figure()
plt.scatter(xedgesbw, databw, c=cbw)
plt.xticks(scale)
plt.xlabel("Edge Count")
plt.ylabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_maxmem-edges.png", dpi=300)

# %%
def filterZero(lst):
    res = []
    for e in lst:
        if e > 0:
            res.append(e)
    return res
        

MaxMemfw = []
MaxMembw = []
MaxMemWOfw = []
MaxMemWObw = []
avgMemfw = [[],[]]
avgMembw = [[],[]]
avgMemWOfw = [[],[]]
avgMemWObw = [[],[]]
absCountfw = [[], []]
absCountbw = [[], []]
absCountWOfw = [[], []]
absCountWObw = [[], []]

for name, app in apps.items():
    if not app.isMemValid():
        continue

    fw = -1
    fwAbs = -1
    bw = -1
    bwAbs = -1
    timeout = False
    for run in app.runsSMP:
        if run.direction == Direction.ForwardsSMP:
            fw = run.maxMemPrecise
            absCountfw[0].append(run.absCountInfoflow)
            absCountfw[1].append(run.absCountAlias)
            MaxMemfw.append(fw)
            avgMemfw[0].append(run.avgMemInfo)
            avgMemfw[1].append(run.avgMemAlias)
            if not run.timeTimeout:
                MaxMemWOfw.append(fw)
                absCountWOfw[0].append(run.absCountInfoflow)
                absCountWOfw[1].append(run.absCountAlias)
                avgMemWOfw[0].append(run.avgMemInfo)
                avgMemWOfw[1].append(run.avgMemAlias)
        elif run.direction == Direction.BackwardsSMP:
            bw = run.maxMemPrecise
            absCountbw[0].append(run.absCountInfoflow)
            absCountbw[1].append(run.absCountAlias)
            MaxMembw.append(bw)
            avgMembw[0].append(run.avgMemInfo)
            avgMembw[1].append(run.avgMemAlias)
            if not run.timeTimeout:
                MaxMemWObw.append(bw)
                avgMemWObw[0].append(run.avgMemInfo)
                avgMemWObw[1].append(run.avgMemAlias)
                absCountWObw[0].append(run.absCountInfoflow)
                absCountWObw[1].append(run.absCountAlias)


percentile = 85
print(f"Maximum Memory Consumption & ${round(np.average(MaxMemfw),2):.2f}MB$ & ${round(np.median(MaxMemfw),2):.2f}MB$ & ${round(np.percentile(MaxMemfw, percentile),2):.2f}MB$\\\\")
print("\\hline")
# print(f"Average Memory Consumption Infoflow & ${round(np.average(filterZero(avgMemfw[0])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemfw[0])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemfw[0]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Alias & ${round(np.average(filterZero(avgMemfw[1])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemfw[1])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemfw[1]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Total & ${round(np.average(filterZero(np.add(avgMemfw[0],avgMemfw[1]))),2):.2f}MB$ & ${round(np.median(filterZero(np.add(avgMemfw[0],avgMemfw[1])/2)),2):.2f}MB$ & ${round(np.percentile(filterZero(np.add(avgMemfw[0],avgMemfw[1])/2), percentile),2):.2f}MB$\\\\")
# print()
print(f"Maximum Memory Consumption & \\multirow{{2}}{{*}}{{${round(np.average(MaxMemWOfw),2):.2f}MB$}} & \\multirow{{2}}{{*}}{{${round(np.median(MaxMemWOfw),2):.2f}MB$}} & \\multirow{{2}}{{*}}{{${round(np.percentile(MaxMemWOfw, percentile),2):.2f}MB$}}\\\\")
print("Without Timeouts & & &\\\\")
# print("\\hline")
# print(f"Average Memory Consumption Infoflow & ${round(np.average(filterZero(avgMembw[0])),2):.2f}MB$ & ${round(np.median(filterZero(avgMembw[0])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMembw[0]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Alias & ${round(np.average(filterZero(avgMembw[1])),2):.2f}MB$ & ${round(np.median(filterZero(avgMembw[1])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMembw[1]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Total & ${round(np.average(filterZero(np.add(avgMembw[0],avgMembw[1]))),2):.2f}MB$ & ${round(np.median(filterZero(np.add(avgMembw[0],avgMembw[1])/2)),2):.2f}MB$ & ${round(np.percentile(filterZero(np.add(avgMembw[0],avgMembw[1])/2), percentile),2):.2f}MB$\\\\")

print()
print()

print(f"Maximum Memory Consumption & ${round(np.average(MaxMembw),2):.2f}MB$ & ${round(np.median(MaxMembw),2):.2f}MB$ & ${round(np.percentile(MaxMembw, percentile),2):.2f}MB$\\\\")
print("\\hline")
# print(f"Average Memory Consumption Infoflow & ${round(np.average(filterZero(avgMemWOfw[0])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemWOfw[0])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemWOfw[0]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Alias & ${round(np.average(filterZero(avgMemWOfw[1])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemWOfw[1])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemWOfw[1]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Total & ${round(np.average(filterZero(np.add(avgMemWOfw[0],avgMemWOfw[1]))),2):.2f}MB$ & ${round(np.median(filterZero(np.add(avgMemWOfw[0],avgMemWOfw[1])/2)),2):.2f}MB$ & ${round(np.percentile(filterZero(np.add(avgMemWOfw[0],avgMemWOfw[1])/2), percentile),2):.2f}MB$\\\\")
# print()
print(f"Maximum Memory Consumption & \\multirow{{2}}{{*}}{{${round(np.average(MaxMemWObw),2):.2f}MB$}} & \\multirow{{2}}{{*}}{{${round(np.median(MaxMemWObw),2):.2f}MB$}} & \\multirow{{2}}{{*}}{{${round(np.percentile(MaxMemWObw, percentile),2):.2f}MB$}}\\\\")
print("Without Timeouts & & &\\\\")
# print("\\hline")
# print(f"Average Memory Consumption Infoflow & ${round(np.average(filterZero(avgMemWObw[0])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemWObw[0])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemWObw[0]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Alias & ${round(np.average(filterZero(avgMemWObw[1])),2):.2f}MB$ & ${round(np.median(filterZero(avgMemWObw[1])),2):.2f}MB$ & ${round(np.percentile(filterZero(avgMemWObw[1]), percentile),2):.2f}MB$\\\\")
# print(f"Average Memory Consumption Total & ${round(np.average(filterZero(np.add(avgMemWObw[0],avgMemWObw[1]))),2):.2f}MB$ & ${round(np.median(filterZero(np.add(avgMemWObw[0],avgMemWObw[1])/2)),2):.2f}MB$ & ${round(np.percentile(filterZero(np.add(avgMemWObw[0],avgMemWObw[1])/2), percentile),2):.2f}MB$\\\\")
# Out:
# Maximum Memory Consumption & $10005.68MB$ & $10459.48MB$ & $15482.98MB$\\
# \hline
# Maximum Memory Consumption & \multirow{2}{*}{$1535.20MB$} & \multirow{2}{*}{$6.98MB$} & \multirow{2}{*}{$4952.20MB$}\\
# Without Timeouts & & &\\
#
#
# Maximum Memory Consumption & $8326.27MB$ & $10008.52MB$ & $14539.64MB$\\
# \hline
# Maximum Memory Consumption & \multirow{2}{*}{$1473.21MB$} & \multirow{2}{*}{$7.33MB$} & \multirow{2}{*}{$1566.61MB$}\\
# Without Timeouts & & &\\

# %%
# Delta of each app with mem

xfw = []
datafw = []
cfw = []
xbw = []
databw = []
cbw = []

delta = []
deltat = []
for name, app in apps.items():
    if not app.isMemValid():
        continue
        
    d = 0
    dt = 0
    r1 = None
    r2 = None
    for run in app.runsSMP:
        if run.direction == Direction.ForwardsSMP:
            d -= run.maxMemPrecise
            dt -= run.dataflowTime
            r1 = run
        elif run.direction == Direction.BackwardsSMP:
            d += run.maxMemPrecise
            dt += run.dataflowTime
            r2 = run
            
#     if abs(d) > 399:
#         rel = app.sources / app.sinks
#         if d < 0:
#             ed1 = round(r1.infoflowEdges / r2.infoflowEdges)
#             ed2 = round(r1.aliasEdges / r2.aliasEdges)
#         else:
#             ed1 = round(r2.infoflowEdges / (1 if r1.infoflowEdges == 0 else r1.infoflowEdges))
#             ed2 = round(r2.aliasEdges / (1 if r1.aliasEdges == 0 else r1.aliasEdges))
# #         print(f"{name}: {d}s with {app.sources}:{app.sinks} and edge {ed1}:{ed2}")
    delta.append(d)
    
#     if np.sign(d) != np.sign(dt) and (dt > 10 or d > 100):
#         print("%s : %s" % (d, dt))

fig = plt.figure()
base = 1000
rounded = int(base * np.ceil(np.abs(delta).max()/base))
plt.hist(delta, bins=np.arange(-rounded, rounded, base), edgecolor='black')
plt.xlabel("$\\Delta$ Maximum Memory Consumption")
plt.ylabel("Frequency")
locs, labels = plt.yticks()
yint = np.arange(0, np.ceil(np.max(locs)), 2)
plt.yticks(yint)
plt.savefig(FIG_PATH + "memHist.png", dpi=300)

# %%
# Correlation between DFTime & MaxMem

datafw = []
maxmemfw = []
datafwTO = []
maxmemfwTO = []
cfw = []
databw = []
maxmembw = []
databwTO = []
maxmembwTO = []
cbw = []

for name, app in apps.items():
    if not app.isMemValid() or not app.isTimeValid():
        continue
        
    for run in app.runsSMP:
        if run.direction == Direction.ForwardsSMP:
            maxmemfw.append(run.maxMemPrecise)
            if run.noTimeout:
                maxmemfwTO.append(run.maxMemPrecise)
        elif run.direction == Direction.BackwardsSMP:
            maxmembw.append(run.maxMemPrecise)
            if run.noTimeout:
                maxmembwTO.append(run.maxMemPrecise)
    for run in app.runs:
        if run.direction == Direction.Forwards:
            datafw.append(run.dataflowTime)
            if run.noTimeout:
                datafwTO.append(run.dataflowTime)
            cfw.append(runToColor(run))
        elif run.direction == Direction.Backwards:
            databw.append(run.dataflowTime)
            if run.noTimeout:
                databwTO.append(run.dataflowTime)
            cbw.append(runToColor(run))


plt.figure()
plt.scatter(maxmemfw, datafw, c=cfw)
mymodel = np.poly1d(np.polyfit(maxmemfw, datafw, 3))
myline = np.linspace(np.min(maxmemfw), np.max(maxmemfw), 100)
plt.plot(myline, mymodel(myline), 'g')
plt.ylabel("Data Flow Time (s)")
plt.xlabel("Maximum Memory Consumption (MB)")
plt.title("Forward")
plt.legend(handles=handles2)
plt.tight_layout()
print(r2_score(datafw, mymodel(maxmemfw)))
plt.savefig(FIG_PATH + "fw_time-mem-correl.png", dpi=300)
plt.figure()
plt.scatter(maxmembw, databw, c=cbw)
mymodel = np.poly1d(np.polyfit(maxmembw, databw, 3))
myline = np.linspace(np.min(maxmembw), np.max(maxmembw), 100)
plt.plot(myline, mymodel(myline), 'g')
plt.ylabel("Data Flow Time (s)")
plt.xlabel("Maximum Memory Consumption (MB)")
plt.title("Backward")
plt.legend(handles=handles2)
plt.tight_layout()
plt.savefig(FIG_PATH + "bw_time-mem-correl.png", dpi=300)
print(r2_score(databw, mymodel(maxmembw)))

print(np.corrcoef(maxmemfw, datafw)[0,1])
print(np.corrcoef(maxmembw, databw)[0,1])

print(stats.spearmanr(maxmemfw, datafw))
print(stats.spearmanr(maxmemfwTO, datafwTO))
print(stats.spearmanr(maxmembw, databw))
print(stats.spearmanr(maxmembwTO, databwTO))
# Out:
# 0.9223548883925612
# 0.9039523062628768
# 0.754305759422893
# 0.8765920062558057
# SpearmanrResult(correlation=0.5555698748570861, pvalue=3.227364770761832e-12)
# SpearmanrResult(correlation=0.6005589334367104, pvalue=0.0031229259839055602)
# SpearmanrResult(correlation=0.7442960606550867, pvalue=6.669844451005666e-25)
# SpearmanrResult(correlation=0.9093596138675463, pvalue=2.2785798962811445e-18)

# %%
ratiofw = []
ratiobw = []

for name, app in apps.items():
    if not app.isTimeValid():
        continue
        
    for run in app.runs:
        if run.direction == Direction.Forwards:
            a = run.absCountAlias
            if a == 0:
                a = 1
            ratiofw.append(run.absCountInfoflow / a)
        elif run.direction == Direction.Backwards:
            a = run.absCountAlias
            if a == 0:
                a = 1
            ratiobw.append(run.absCountInfoflow / a)

print(f"Avg {np.average(ratiofw)} Median {np.median(ratiofw)} Percentile {np.percentile(ratiofw, 85)}")
print(f"Avg {np.average(ratiobw)} Median {np.median(ratiobw)} Percentile {np.percentile(ratiobw, 85)}")
# Out:
# Avg 9.46811271282259 Median 2.860437101779781 Percentile 3.5513460295733688
# Avg 0.9242235451564107 Median 0.4260926019040564 Percentile 1.1474001591915837

# %%
apkList = [
    "ru.beeline.services.apk",
    "com.backgrounderaser.cutout.photoeditor.apk",
    "com.microsoft.office.officehubrow.apk",
    "com.autoscout24.apk",
    "hr.palamida.apk",
    "com.kinky.fetlifestyle.apk",
    "com.apartmentlist.mobile.apk",
    "com.grabtaxi.passenger.apk",
    "com.murphy.driverewards.apk",
    "com.rcmbusiness.apk",
    "dbx.taiwantaxi.apk",
    "com.socialnetwork.hookupsapp.apk",
    "com.clusterdev.hindikeyboard.apk",
    "document.scanner.scan.pdf.image.text.apk",
    "app.habitaclia2.apk",
    "com.opera.touch.apk",
    "com.astepanov.mobile.mathforkids.apk",
    "com.zoho.sheet.android.apk",
    "au.com.auspost.android.apk",
    "com.buildium.resident.android.apk",
    "com.jrtstudio.music.apk",
    "com.onlyoffice.documents.apk",
    "com.cloudmosa.puffinFree.apk",
    "com.spinmaster.enterprise.colleggtibles.apk",
    "com.match.android.matchmobile.apk",
    "com.uba.vericash.apk",
    "com.musicplayer.music.apk",
    "com.microsoft.office.onenote.apk",
    "it.casa.app.apk",
    "com.fuib.android.spot.online.apk",
    "com.finlim.forkapp.apk",
    "app.quiktrip.com.quiktrip.apk",
    "com.sendo.apk"
]

import json
from jsoncomment import JsonComment

def getBranchingFactorForMethod(lst, invert):
    lst = lst.copy()
    if invert:
        lst.reverse()
    
    bf = []
    incoming = lst[0]
    for i in range(1, len(lst)):
        if incoming == 0:
            continue
        outcoming = lst[i]
        bf.append(outcoming/incoming)
    if len(bf) == 0:
        return 0
    return np.average(bf)

parser = JsonComment(json)
xvmFw = []
xvmBw = []
xbfFw = []
xbfBw = []
ydfFw = []
ydfBw = []
for apk in apkList:
    with open(f"taintnum/{apk}i.txt") as f:
        fwi = parser.load(f)
    with open(f"taintnum/{apk}a.txt") as f:
        fwa = parser.load(f)
    with open(f"taintnum/bw{apk}i.txt") as f:
        bwi = parser.load(f)
    with open(f"taintnum/bw{apk}a.txt") as f:
        bwa = parser.load(f)
        
    methodsFwI = set(fwi.keys())
    methodsFwA = set(fwa.keys())
    methodsFw = methodsFwI.union(methodsFwA)
    methodsBwI = set(bwi.keys())
    methodsBwA = set(bwa.keys())
    methodsBw = methodsBwI.union(methodsBwA)
    d = 0
    for run in apps[apk].runs:
        if run.direction == Direction.Forwards:
            d -= (run.dataflowTime)
        elif run.direction == Direction.Backwards:
            d += (run.dataflowTime)
    print(f"{np.sign(d)}{apk}: {len(methodsFw)} ({len(fwi.keys())}:{len(fwa.keys())}) vs {len(methodsBw)} ({len(bwi.keys())}:{len(bwa.keys())})")
    
    bfFwI = {}
    for m in methodsFwI:
        bfFwI[m] = getBranchingFactorForMethod(fwi[m], False)
    bfFwA = {}
    for m in methodsFwA:
        bfFwA[m] = getBranchingFactorForMethod(fwa[m], True)
    bfBwI = {}
    for m in methodsBwI:
        bfBwI[m] = getBranchingFactorForMethod(bwi[m], True)
    bfBwA = {}
    for m in methodsBwA:
        bfBwA[m] = getBranchingFactorForMethod(bwa[m], False)
    print(f"Mean Branching Factor: {round(np.average(list(bfFwI.values())),2)}:{round(np.average(list(bfFwA.values())),2)} vs {round(np.average(list(bfBwI.values())),2)}:{round(np.average(list(bfBwA.values())),2)}")
    bfSumFw = (np.average(list(bfFwI.values()))+np.average(list(bfFwA.values())))/2
    bfSumBw = (np.average(list(bfBwI.values()))+np.average(list(bfBwA.values())))/2
    xbfFw.append(bfSumFw)
    xbfBw.append(bfSumBw)
    for run in apps[apk].runs:
        if run.direction == Direction.Forwards:
            ydfFw.append(run.dataflowTime)
        elif run.direction == Direction.Backwards:
            ydfBw.append(run.dataflowTime)
    xvmFw.append(len(methodsFw))
    xvmBw.append(len(methodsBw))
    
    intermI = methodsFwI.intersection(methodsBwI)
    intersectFwI = []
    intersectBwI = []
    for m in intermI:
        intersectFwI.append(getBranchingFactorForMethod(fwi[m], False))
        intersectBwI.append(getBranchingFactorForMethod(bwi[m], True))
    intermA = methodsFwA.intersection(methodsBwA)
    intersectFwA = []
    intersectBwA = []
    for m in intermA:
        intersectFwA.append(getBranchingFactorForMethod(fwa[m], True))
        intersectBwA.append(getBranchingFactorForMethod(bwa[m], False))
    print(f"Intersect BF: {round(np.average(intersectFwI), 2)}:{round(np.average(intersectFwA), 2)} vs {round(np.average(intersectBwI), 2)}:{round(np.average(intersectBwA), 2)}")
    
plt.figure()
plt.scatter(xbfFw, ydfFw)
plt.xlabel("Average Branching Factor")
plt.ylabel("Data Flow Time (s)")
plt.title("Forward")
plt.tight_layout()
plt.figure()
plt.scatter(xbfBw, ydfBw)
plt.xlabel("Average Branching Factor")
plt.ylabel("Data Flow Time (s)")
plt.title("Backward")
plt.tight_layout()
# plt.scatter(np.subtract(xbfBw,xbfFw), np.subtract(ydfBw,ydfFw))
# plt.xlabel("Branching Factor Ratio")
# plt.ylabel("Data Flow Time (s)")
# plt.tight_layout()
# Out:
# -1ru.beeline.services.apk: 887 (886:679) vs 84 (81:48)
# Mean Branching Factor: 3.93:35.96 vs 1.01:0.97
# Intersect BF: 0.8:0.62 vs 0.8:0.0
# -1com.backgrounderaser.cutout.photoeditor.apk: 1390 (1378:1037) vs 10 (10:6)
# Mean Branching Factor: 3.03:6.33 vs 0.95:0.0
# Intersect BF: nan:nan vs nan:nan
# /usr/lib64/python3.9/site-packages/numpy/lib/function_base.py:380: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /usr/lib64/python3.9/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# -1com.microsoft.office.officehubrow.apk: 1983 (1971:1286) vs 89 (81:78)
# Mean Branching Factor: 2.78:37.78 vs 6.1:7.0
# Intersect BF: 1.05:0.5 vs 10.18:1.17
# -1com.autoscout24.apk: 2092 (2083:1528) vs 47 (45:47)
# Mean Branching Factor: 2.44:8.01 vs 5.34:4.84
# Intersect BF: nan:nan vs nan:nan
# -1hr.palamida.apk: 2217 (2213:1581) vs 15 (14:11)
# Mean Branching Factor: 2.33:42.11 vs 0.65:0.12
# Intersect BF: 1.19:1.74 vs 0.0:0.0
# -1com.kinky.fetlifestyle.apk: 1476 (1447:980) vs 10 (9:6)
# Mean Branching Factor: 2.07:32.0 vs 0.95:0.22
# Intersect BF: nan:nan vs nan:nan
# -1com.apartmentlist.mobile.apk: 1221 (1214:848) vs 179 (165:168)
# Mean Branching Factor: 1.81:3.98 vs 4.0:169.42
# Intersect BF: 0.4:0.14 vs 2.82:0.52
# -1com.grabtaxi.passenger.apk: 878 (846:517) vs 10 (9:6)
# Mean Branching Factor: 39.31:4.99 vs 1.06:0.22
# Intersect BF: nan:nan vs nan:nan
# -1com.murphy.driverewards.apk: 1314 (1313:938) vs 289 (278:220)
# Mean Branching Factor: 3.31:26.11 vs 2.31:3.11
# Intersect BF: 0.52:nan vs 0.32:nan
# -1com.rcmbusiness.apk: 1850 (1838:1258) vs 11 (11:2)
# Mean Branching Factor: 2.58:3.95 vs 0.88:0.0
# Intersect BF: nan:nan vs nan:nan
# -1dbx.taiwantaxi.apk: 973 (955:442) vs 153 (147:101)
# Mean Branching Factor: 19.49:11.8 vs 1.27:1.71
# Intersect BF: 0.61:0.34 vs 2.25:1.43
# -1com.socialnetwork.hookupsapp.apk: 1569 (1542:1054) vs 10 (10:9)
# Mean Branching Factor: 2.32:6.11 vs 0.31:1.62
# Intersect BF: 1.37:0.0 vs 0.42:2.0
# -1com.clusterdev.hindikeyboard.apk: 1435 (1425:1008) vs 10 (10:3)
# Mean Branching Factor: 2.32:7.83 vs 0.26:0.0
# Intersect BF: nan:nan vs nan:nan
# -1document.scanner.scan.pdf.image.text.apk: 2415 (2398:1799) vs 26 (25:15)
# Mean Branching Factor: 2.28:4.73 vs 1.17:1.25
# Intersect BF: 1.15:1.0 vs 1.19:1.0
# -1app.habitaclia2.apk: 1459 (1455:1089) vs 10 (9:6)
# Mean Branching Factor: 3.02:15.37 vs 1.06:0.22
# Intersect BF: nan:nan vs nan:nan
# -1com.opera.touch.apk: 1473 (1462:1030) vs 13 (13:1)
# Mean Branching Factor: 2.09:8.52 vs 0.12:0.0
# Intersect BF: nan:nan vs nan:nan
# -1com.astepanov.mobile.mathforkids.apk: 1001 (1001:782) vs 76 (75:71)
# Mean Branching Factor: 3.43:7.5 vs 4.92:3.62
# Intersect BF: 1.65:0.11 vs 6.72:2.24
# -1com.zoho.sheet.android.apk: 2841 (2826:1945) vs 77 (71:65)
# Mean Branching Factor: 2.28:13.79 vs 2.14:3.09
# Intersect BF: 0.88:0.0 vs 1.22:0.0
# -1au.com.auspost.android.apk: 1203 (1197:782) vs 13 (12:12)
# Mean Branching Factor: 1.92:7.05 vs 0.61:1.28
# Intersect BF: 1.08:1.01 vs 0.42:1.06
# -1com.buildium.resident.android.apk: 2331 (2314:1495) vs 6 (6:3)
# Mean Branching Factor: 2.05:66.28 vs 0.17:0.0
# Intersect BF: nan:nan vs nan:nan
# 1com.jrtstudio.music.apk: 251 (251:178) vs 114 (112:104)
# Mean Branching Factor: 2.94:1.9 vs 7.69:17.26
# Intersect BF: 0.98:0.0 vs 1.12:1.45
# -1com.onlyoffice.documents.apk: 1720 (1700:1285) vs 10 (9:6)
# Mean Branching Factor: 2.68:37.27 vs 0.89:0.22
# Intersect BF: nan:nan vs nan:nan
# 1com.cloudmosa.puffinFree.apk: 7 (7:2) vs 112 (104:98)
# Mean Branching Factor: 0.36:0.0 vs 12.61:7.18
# Intersect BF: nan:nan vs nan:nan
# 1com.spinmaster.enterprise.colleggtibles.apk: 105 (103:63) vs 147 (147:110)
# Mean Branching Factor: 1.92:1.1 vs 10.93:9.09
# Intersect BF: 2.08:0.38 vs 1.96:1.26
# -1com.match.android.matchmobile.apk: 2639 (2547:1761) vs 69 (67:49)
# Mean Branching Factor: 2.34:2.76 vs 1.78:5.11
# Intersect BF: 1.57:0.52 vs 3.39:2.3
# 1com.uba.vericash.apk: 2 (2:0) vs 166 (165:158)
# Mean Branching Factor: 0.0:nan vs 75.39:33.05
# Intersect BF: nan:nan vs nan:nan
# -1com.musicplayer.music.apk: 2650 (2631:1912) vs 1 (1:1)
# Mean Branching Factor: 2.4:8.18 vs 0.0:0.0
# Intersect BF: nan:nan vs nan:nan
# -1com.microsoft.office.onenote.apk: 1491 (1482:969) vs 3 (3:1)
# Mean Branching Factor: 1.99:7.2 vs 0.44:0.0
# Intersect BF: nan:nan vs nan:nan
# -1it.casa.app.apk: 1233 (1233:940) vs 13 (12:7)
# Mean Branching Factor: 3.62:6.88 vs 0.79:0.19
# Intersect BF: nan:nan vs nan:nan
# -1com.fuib.android.spot.online.apk: 1762 (1752:1205) vs 10 (9:6)
# Mean Branching Factor: 2.36:11.15 vs 0.95:0.22
# Intersect BF: nan:nan vs nan:nan
# 1com.finlim.forkapp.apk: 682 (681:525) vs 188 (182:162)
# Mean Branching Factor: 2.08:3.75 vs 39.0:11.79
# Intersect BF: nan:nan vs nan:nan
# -1app.quiktrip.com.quiktrip.apk: 1938 (1930:1074) vs 213 (208:181)
# Mean Branching Factor: 1.5:4.17 vs 10.93:6.59
# Intersect BF: 1.12:0.84 vs 2.31:1.28
# -1com.sendo.apk: 3720 (3676:2302) vs 392 (366:300)
# Mean Branching Factor: 1.82:1.81 vs 4.37:2.65
# Intersect BF: 1.34:6.58 vs 1.85:3.43

# %%
import json
from jsoncomment import JsonComment
import re

def escape(string):
    string = "[" + string + "]"
    for m in re.finditer(r'"Stmt": "(.*?)",\n', string):
        g = m.group(1)
        string = string.replace(g, g.replace('"', '\\"'))
#         print(string)
    return string

def sumData(data, key):
    donelst = []
    mysum = 0
    for entry in data:
        if entry["Method"] in donelst:
            continue
        mysum += int(entry[key])
        donelst.append(entry["Method"])
    return mysum

parser = JsonComment(json)
ufw = []
ubw = []
callfw = []
callbw = []
calleesfw = []
calleesbw = []
delta = []
rf = []
rb = []
for apk in apkList:
    with open(f"sslogs/{apk}.txt") as f:
        fw = parser.loads(escape(f.read()))
    with open(f"sslogs/bw{apk}.txt") as f:
        bw = parser.loads(escape(f.read()))
    ufw.append(sumData(fw, "Units"))
    ubw.append(sumData(bw, "Units"))
    callfw.append(sumData(fw, "Calls"))
    callbw.append(sumData(bw, "Calls"))
    calleesfw.append(sumData(fw, "Callers"))
    calleesbw.append(sumData(bw, "Callers"))
    d=0
    for run in apps[apk].runs:
        if run.direction == Direction.Forwards:
            rf.append(run.dataflowTime)
            d -= (run.dataflowTime)
        elif run.direction == Direction.Backwards:
            rb.append(run.dataflowTime)
            d += (run.dataflowTime)
    delta.append(d)

#     print(f"{np.sign(d)}{apk}: Units {ufw}:{ubw}, Calls {callfw}:{callbw}, Callers {calleesfw}:{calleesbw}")
    
plt.figure()
plt.scatter(np.divide(np.subtract(ubw, ufw), ufw), delta)
plt.xlabel("Unit Ratio")
plt.ylabel("Delta Data Flow Time (s)")
plt.tight_layout()
plt.figure()
plt.scatter(np.divide(np.subtract(callbw, callfw), callfw), delta)
plt.xlabel("Caller Ratio")
plt.ylabel("Delta Data Flow Time (s)")
plt.tight_layout()
plt.figure()
plt.scatter(np.divide(np.subtract(calleesbw, calleesfw), calleesfw), delta)
plt.xlabel("Callees Ratio")
plt.ylabel("Delta Data Flow Time (s)")
plt.tight_layout()

# %%
import glob
import os


pfw = []
absfw = []
spfw = []
pbw = []
absbw = []
spbw = []

delta = []
deltaPre = []
deltaPre2 = []
deltaCaller = []
deltaCallee = []
def mySum(data, key):
    mysum = 0
    for entry in data:
        mysum += entry[key]
    return mysum

for name, app in apps.items():
    if not os.path.isfile(f"./predict/{name}.txt"):
        continue
    if not app.isTimeValid():
        continue

    print(f"{name}")
    with open(f"./predict/{name}.txt") as f:
        txt = parser.load(f)
    fw = txt["Forward"]
    bw = txt["Backward"]
    fwprop = mySum(fw, "Propagations")
    bwprop = mySum(bw, "Propagations")
    if fwprop > 10000 or bwprop > 10000:
        continue
    fwcallee = mySum(fw, "Callee")
    bwcallee = mySum(bw, "Callee")
    fwcaller = mySum(fw, "Caller")
    bwcaller = mySum(bw, "Caller")
    fwtaints = (mySum(fw, "OutSets"))
    bwtaints = (mySum(bw, "OutSets"))
    spfw.append(fwprop)
    spbw.append(bwprop)
    absfw.append(fwcaller+fwcallee)
    absbw.append(bwcaller+bwcallee)
    d = 0
    for run in apps[name].runs:
        if run.direction == Direction.Forwards:
            pfw.append(run.absCountInfoflow)
            d -= (run.dataflowTime)
        elif run.direction == Direction.Backwards:
            pbw.append(run.absCountInfoflow)            
            d += (run.dataflowTime)
    delta.append(d)
    deltaPre.append(bwprop-fwprop)
    deltaPre2.append(bwtaints - fwtaints)
    deltaCaller.append(bwcaller - fwcaller)
    deltaCallee.append(bwcallee - fwcallee)
    print(f"{np.sign(d)}({bwprop-fwprop}/{bwcaller-fwcaller}/{bwcallee-fwcaller}) {name}: {fwprop}/{fwcaller}/{fwcallee} vs {bwprop}/{bwcaller}/{bwcallee}")
# plt.figure()
# plt.scatter(pfw, spfw)
# plt.xlabel("Infoflow Edge Count")
# plt.ylabel("Preanalysis Edge Count")
# plt.tight_layout()
# plt.figure()
# plt.scatter(pbw, spbw)
# plt.xlabel("Infoflow Edge Count")
# plt.ylabel("Preanalysis Edge Count")
# plt.tight_layout()
# plt.figure()
# plt.scatter(pfw, absfw)
# plt.xlabel("Leaving Abstractions")
# plt.ylabel("Preanalysis Edge Count")
# plt.tight_layout()
# plt.figure()
# plt.scatter(pbw, absbw)
# plt.xlabel("Leaving Abstractions")
# plt.ylabel("Preanalysis Edge Count")
# plt.tight_layout()

import matplotlib.patches as patches
plt.figure()
plt.scatter(delta, deltaPre)
xMax = (round(np.max(np.absolute(delta))/100)+1)*100
yMax = (round(np.max(np.absolute(deltaPre))/500)+1)*500
xscale = np.arange(-xMax, xMax, 100)
yscale = np.arange(-yMax, yMax, 500)
plt.xticks(xscale)
plt.yticks(yscale)
# plt.title("Propagations")
ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.set_xlabel("Analysis Delta")
ax.xaxis.set_label_coords(1.1, 0.5)
ax.set_ylabel("Preanalysis Delta", rotation=0)
ax.yaxis.set_label_coords(0.5, -0.1)
ax.add_patch(
    patches.Rectangle((0, 0), xMax, yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, -yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, yMax, color=(1,0,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), xMax, -yMax, color=(1,0,0,0.1)))
plt.tight_layout()

plt.savefig(FIG_PATH + "preanal.png", dpi=300)



plt.figure()
plt.scatter(delta, deltaCallee)
xMax = (round(np.max(np.absolute(delta))/100)+1)*100
yMax = (round(np.max(np.absolute(deltaCallee))/100)+1)*100
xscale = np.arange(-xMax, xMax, 100)
yscale = np.arange(-yMax, yMax, 100)
plt.xticks(xscale)
plt.yticks(yscale)
plt.title("Taint Number")
ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.set_xlabel("Analysis Delta")
ax.xaxis.set_label_coords(1.1, 0.5)
ax.set_ylabel("Preanalysis Delta", rotation=0)
ax.yaxis.set_label_coords(0.5, -0.1)
ax.add_patch(
    patches.Rectangle((0, 0), xMax, yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, -yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, yMax, color=(1,0,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), xMax, -yMax, color=(1,0,0,0.1)))
plt.tight_layout()

plt.figure()
plt.scatter(delta, deltaCaller)
xMax = (round(np.max(np.absolute(delta))/100)+1)*100
yMax = (round(np.max(np.absolute(deltaCaller))/100)+1)*100
xscale = np.arange(-xMax, xMax, 100)
yscale = np.arange(-yMax, yMax, 100)
plt.xticks(xscale)
plt.yticks(yscale)
plt.title("Taint Number")
ax = plt.gca()
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.set_xlabel("Analysis Delta")
ax.xaxis.set_label_coords(1.1, 0.5)
ax.set_ylabel("Preanalysis Delta", rotation=0)
ax.yaxis.set_label_coords(0.5, -0.1)
ax.add_patch(
    patches.Rectangle((0, 0), xMax, yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, -yMax, color=(0,1,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), -xMax, yMax, color=(1,0,0,0.1)))
ax.add_patch(
    patches.Rectangle((0, 0), xMax, -yMax, color=(1,0,0,0.1)))
plt.tight_layout()
# Out:
# jp.co.canon.oip.android.opal.apk
# 1(-66/-1/14) jp.co.canon.oip.android.opal.apk: 99/2/12 vs 33/1/16
# com.amazon.dee.app.apk
# 1(-337/5/112) com.amazon.dee.app.apk: 699/28/185 vs 362/33/140
# com.musicplayer.player.mp3player.white.apk
# 1(-463/-1/0) com.musicplayer.player.mp3player.white.apk: 465/1/79 vs 2/0/1
# com.nhn.android.navertv.apk
# 1(-679/12/66) com.nhn.android.navertv.apk: 861/20/231 vs 182/32/86
# ru.beeline.services.apk
# -1(-479/-8/59) ru.beeline.services.apk: 702/10/197 vs 223/2/69
# com.fsn.nds.apk
# 0(-313/7/203) com.fsn.nds.apk: 1022/14/258 vs 709/21/217
# com.fivory.prod.apk
# com.backgrounderaser.cutout.photoeditor.apk
# -1(-162/5/29) com.backgrounderaser.cutout.photoeditor.apk: 227/1/12 vs 65/6/30
# com.microsoft.office.officehubrow.apk
# -1(-136/0/34) com.microsoft.office.officehubrow.apk: 236/2/13 vs 100/2/36
# au.com.parrotfish.phonemic.lite.apk
# com.autoscout24.apk
# -1(-218/-1/1) com.autoscout24.apk: 234/3/16 vs 16/2/4
# hr.palamida.apk
# -1(-1221/-9/-5) hr.palamida.apk: 1272/15/266 vs 51/6/10
# com.kinky.fetlifestyle.apk
# -1(-302/4/6) com.kinky.fetlifestyle.apk: 322/2/44 vs 20/6/8
# cz.seznam.novinky.apk
# 1(-1214/13/37) cz.seznam.novinky.apk: 1361/0/97 vs 147/13/37
# com.euronews.express.apk
# 1(-435/10/141) com.euronews.express.apk: 801/6/178 vs 366/16/147
# com.apartmentlist.mobile.apk
# -1(-413/4/11) com.apartmentlist.mobile.apk: 573/2/105 vs 160/6/13
# tw.com.ctitv.ctitvnews.apk
# 0(-439/0/1) tw.com.ctitv.ctitvnews.apk: 472/10/84 vs 33/10/11
# nineNewsAlerts.nine.com.apk
# 1(-76/-1/63) nineNewsAlerts.nine.com.apk: 276/5/15 vs 200/4/68
# mnn.Android.apk
# -1(-511/11/57) mnn.Android.apk: 712/5/125 vs 201/16/62
# com.ubieva.cura.userapp.droid.apk
# 0(-92/5/7) com.ubieva.cura.userapp.droid.apk: 112/1/36 vs 20/6/8
# com.google.android.apps.seekh.apk
# -1(-800/-8/-9) com.google.android.apps.seekh.apk: 807/9/30 vs 7/1/0
# com.murphy.driverewards.apk
# -1(-106/7/30) com.murphy.driverewards.apk: 235/1/14 vs 129/8/31
# com.vuclip.viu.apk
# 1(-1204/-17/142) com.vuclip.viu.apk: 1788/37/381 vs 584/20/179
# com.touchtype.swiftkey.apk
# 1(-1661/-12/1) com.touchtype.swiftkey.apk: 1724/16/240 vs 63/4/17
# com.rcmbusiness.apk
# -1(-220/-1/3) com.rcmbusiness.apk: 227/1/12 vs 7/0/4
# com.orange.kidspiano.music.songs.apk
# com.creditkarma.mobile.apk
# 1(-270/13/55) com.creditkarma.mobile.apk: 474/0/57 vs 204/13/55
# com.originatorkids.EndlessWordplay.apk
# com.flur.apk
# 1(-431/0/45) com.flur.apk: 603/13/153 vs 172/13/58
# com.videocall.randomfriendvideo.apk
# 1(-497/-1/47) com.videocall.randomfriendvideo.apk: 620/2/121 vs 123/1/49
# dbx.taiwantaxi.apk
# -1(-1723/-14/68) dbx.taiwantaxi.apk: 1981/22/464 vs 258/8/90
# com.socialnetwork.hookupsapp.apk
# -1(-237/-1/2) com.socialnetwork.hookupsapp.apk: 262/1/24 vs 25/0/3
# com.clusterdev.hindikeyboard.apk
# -1(-227/-3/6) com.clusterdev.hindikeyboard.apk: 245/3/23 vs 18/0/9
# document.scanner.scan.pdf.image.text.apk
# -1(-129/1/29) document.scanner.scan.pdf.image.text.apk: 223/1/12 vs 94/2/30
# com.splendapps.voicerec.apk
# -1(-198/-1/5) com.splendapps.voicerec.apk: 227/1/12 vs 29/0/6
# app.habitaclia2.apk
# -1(-453/5/7) app.habitaclia2.apk: 473/1/72 vs 20/6/8
# com.espn.score_center.apk
# com.fineapp.yogiyo.apk
# 1(-677/14/73) com.fineapp.yogiyo.apk: 865/8/193 vs 188/22/81
# com.thredup.android.apk
# 1(-563/6/116) com.thredup.android.apk: 1005/9/264 vs 442/15/125
# com.opera.touch.apk
# -1(-420/-33/-29) com.opera.touch.apk: 427/33/63 vs 7/0/4
# com.astepanov.mobile.mathforkids.apk
# -1(-200/2/37) com.astepanov.mobile.mathforkids.apk: 310/1/44 vs 110/3/38
# de.etecture.ekz.onleihe.apk
# -1(708/14/264) de.etecture.ekz.onleihe.apk: 492/4/78 vs 1200/18/268
# com.kevinbradford.games.pklg2.apk
# ua.insomnia.kenya.newsi.apk
# 1(-448/5/29) ua.insomnia.kenya.newsi.apk: 516/2/83 vs 68/7/31
# com.money91.apk
# -1(-153/18/125) com.money91.apk: 658/5/103 vs 505/23/130
# com.zoho.sheet.android.apk
# -1(-448/-6/0) com.zoho.sheet.android.apk: 459/6/104 vs 11/0/6
# com.facebook.mlite.apk
# 0(-506/8/23) com.facebook.mlite.apk: 554/2/88 vs 48/10/25
# au.com.auspost.android.apk
# -1(-369/-3/-1) au.com.auspost.android.apk: 382/3/41 vs 13/0/2
# com.dating.find_love.apk
# 1(-143/0/30) com.dating.find_love.apk: 269/7/22 vs 126/7/37
# com.buildium.resident.android.apk
# -1(-541/-5/-1) com.buildium.resident.android.apk: 550/5/112 vs 9/0/4
# com.jrtstudio.music.apk
# 1(-265/2/42) com.jrtstudio.music.apk: 365/0/42 vs 100/2/42
# com.covalent.kippo.apk
# 0(-254/1/-1) com.covalent.kippo.apk: 260/1/20 vs 6/2/0
# com.onlyoffice.documents.apk
# -1(-207/5/7) com.onlyoffice.documents.apk: 227/1/12 vs 20/6/8
# com.cloudmosa.puffinFree.apk
# 1(69/10/73) com.cloudmosa.puffinFree.apk: 238/1/47 vs 307/11/74
# com.spinmaster.enterprise.colleggtibles.apk
# 1(228/-4/55) com.spinmaster.enterprise.colleggtibles.apk: 39/12/29 vs 267/8/67
# com.match.android.matchmobile.apk
# -1(-481/-1/42) com.match.android.matchmobile.apk: 677/7/173 vs 196/6/49
# com.belk.android.belk.apk
# -1(-254/12/89) com.belk.android.belk.apk: 540/1/81 vs 286/13/90
# com.lyrebirdstudio.face_camera.apk
# 1(-374/5/59) com.lyrebirdstudio.face_camera.apk: 535/2/88 vs 161/7/61
# com.lyrebirdstudio.tbt.apk
# 1(-438/5/42) com.lyrebirdstudio.tbt.apk: 535/2/88 vs 97/7/44
# photocollage.photoeditor.collagemaker.apk
# 1(-113/-1/43) photocollage.photoeditor.collagemaker.apk: 227/1/12 vs 114/0/44
# com.uba.vericash.apk
# 1(-28/6/15) com.uba.vericash.apk: 85/0/7 vs 57/6/15
# com.rubenmayayo.reddit.apk
# 1(-109/8/44) com.rubenmayayo.reddit.apk: 291/4/29 vs 182/12/48
# com.musicplayer.music.apk
# -1(-432/-3/19) com.musicplayer.music.apk: 477/3/73 vs 45/0/22
# com.microsoft.office.onenote.apk
# -1(-209/-2/1) com.microsoft.office.onenote.apk: 233/3/12 vs 24/1/4
# it.casa.app.apk
# -1(-200/5/11) it.casa.app.apk: 227/1/12 vs 27/6/12
# info.yogantara.utmgeomap.apk
# 1(-246/-2/-2) info.yogantara.utmgeomap.apk: 307/5/56 vs 61/3/3
# com.thesouledstore.apk
# -1(-474/-3/28) com.thesouledstore.apk: 563/11/114 vs 89/8/39
# ir.tgbs.peccharge.apk
# 1(-876/-3/22) ir.tgbs.peccharge.apk: 947/7/139 vs 71/4/29
# fr.cnaf.mobile.moncompte.apk
# 0(5/0/3) fr.cnaf.mobile.moncompte.apk: 5/0/1 vs 10/0/3
# com.marlustudio.englishforkids.apk
# com.Slack.apk
# 1(-515/-3/11) com.Slack.apk: 541/3/70 vs 26/0/14
# com.fuib.android.spot.online.apk
# -1(-207/5/7) com.fuib.android.spot.online.apk: 227/1/12 vs 20/6/8
# camsurf.com.apk
# 0(-1/6/8) camsurf.com.apk: 21/0/8 vs 20/6/8
# com.lego.friends.heartlake.apk
# 1(-71/0/4) com.lego.friends.heartlake.apk: 85/0/7 vs 14/0/4
# com.abbyy.mobile.textgrabber.full.apk
# -1(-384/-2/-1) com.abbyy.mobile.textgrabber.full.apk: 386/2/62 vs 2/0/1
# org.familysearch.mobile.apk
# 1(737/48/260) org.familysearch.mobile.apk: 291/1/18 vs 1028/49/261
# com.radio.fmradio.apk
# -1(-364/2/36) com.radio.fmradio.apk: 456/4/92 vs 92/6/40
# com.mufumbo.android.recipe.search.apk
# 1(-352/3/7) com.mufumbo.android.recipe.search.apk: 376/3/57 vs 24/6/10
# com.tacobell.ordering.apk
# com.newspaperdirect.pressreader.android.apk
# 1(291/14/160) com.newspaperdirect.pressreader.android.apk: 996/6/171 vs 1287/20/166
# com.khorasannews.akharinkhabar.apk
# 0(-488/-4/29) com.khorasannews.akharinkhabar.apk: 577/9/116 vs 89/5/38
# com.cabs.apk
# -1(46/13/103) com.cabs.apk: 508/2/76 vs 554/15/105
# com.amazon.mShop.android.shopping.apk
# -1(4/7/127) com.amazon.mShop.android.shopping.apk: 469/21/144 vs 473/28/148
# de.number26.android.apk
# 1(-390/0/30) de.number26.android.apk: 454/4/73 vs 64/4/34
# com.indianexpress.android.apk
# 1(-305/7/64) com.indianexpress.android.apk: 461/6/57 vs 156/13/70
# com.hk01.news_app.apk
# -1(-487/7/42) com.hk01.news_app.apk: 595/2/105 vs 108/9/44
# com.aspiro.tidal.apk
# 1(-815/2/15) com.aspiro.tidal.apk: 994/16/198 vs 179/18/31
# com.skyhealth.glucosebuddyfree.apk
# 0(-838/-15/21) com.skyhealth.glucosebuddyfree.apk: 926/23/235 vs 88/8/44
# com.croquis.zigzag.apk
# 1(-524/8/19) com.croquis.zigzag.apk: 574/2/95 vs 50/10/21
# com.yoox.apk
# 1(2962/174/577) com.yoox.apk: 527/2/99 vs 3489/176/579
# com.application.zomato.apk
# com.streema.simpleradio.apk
# -1(-576/4/37) com.streema.simpleradio.apk: 668/3/145 vs 92/7/40
# vivino.web.app.apk
# 1(-1060/13/102) vivino.web.app.apk: 1419/2/146 vs 359/15/104
# com.nbaimd.gametime.nba2011.apk
# 0(-872/6/33) com.nbaimd.gametime.nba2011.apk: 1049/14/245 vs 177/20/47
# com.lezhin.comics.apk
# 0(-506/10/47) com.lezhin.comics.apk: 854/6/139 vs 348/16/53
# com.xfinity.cloudtvr.apk
# 1(231/14/160) com.xfinity.cloudtvr.apk: 470/3/94 vs 701/17/163
# sweet.selfie.lite.apk
# 1(-12/7/101) sweet.selfie.lite.apk: 280/2/31 vs 268/9/103
# com.yy.hiyo.apk
# 1(431/220/289) com.yy.hiyo.apk: 1473/28/375 vs 1904/248/317
# com.urbanclap.urbanclap.apk
# 0(-957/5/68) com.urbanclap.urbanclap.apk: 1296/17/278 vs 339/22/85
# com.resmed.myair.apk
# 1(42/4/26) com.resmed.myair.apk: 48/1/13 vs 90/5/27
# taxi.android.client.apk
# 1(-314/4/68) taxi.android.client.apk: 875/14/221 vs 561/18/82
# ma.safe.bnau.apk
# 1(-499/5/38) ma.safe.bnau.apk: 588/1/81 vs 89/6/39
# com.ak.ta.dainikbhaskar.activity.apk
# 1(-374/5/20) com.ak.ta.dainikbhaskar.activity.apk: 599/5/71 vs 225/10/25
# com.finlim.forkapp.apk
# 1(-507/5/8) com.finlim.forkapp.apk: 532/2/90 vs 25/7/10
# com.planner5d.swedishhomedesign.apk
# 1(63/16/108) com.planner5d.swedishhomedesign.apk: 446/1/62 vs 509/17/109
# com.nhn.android.webtoon.apk
# 1(-363/26/80) com.nhn.android.webtoon.apk: 545/6/106 vs 182/32/86
# com.ace.android.apk
# com.lafiya.telehealth.apk
# com.waitrapp.apk
# 0(-429/14/42) com.waitrapp.apk: 697/2/145 vs 268/16/44
# com.clouthub.clouthub.apk
# com.poqstudio.app.platform.boohoo.apk
# -1(-1620/-98/-70) com.poqstudio.app.platform.boohoo.apk: 1744/113/278 vs 124/15/43
# com.pinger.textfree.apk
# -1(-1092/12/102) com.pinger.textfree.apk: 1512/7/441 vs 420/19/109
# co.brainly.apk
# -1(-222/17/32) co.brainly.apk: 491/1/62 vs 269/18/33
# com.app.rondevo.apk
# com.adobe.reader.apk
# -1(241/23/182) com.adobe.reader.apk: 230/4/12 vs 471/27/186
# com.tubitv.apk
# 0(-854/2/8) com.tubitv.apk: 894/5/208 vs 40/7/13
# com.dazz.hoop.apk
# 1(-333/0/96) com.dazz.hoop.apk: 704/16/122 vs 371/16/112
# com.sinyee.babybus.engineering.apk
# 1(-299/-4/0) com.sinyee.babybus.engineering.apk: 319/4/43 vs 20/0/4
# com.meesho.supply.apk
# -1(-1252/-12/75) com.meesho.supply.apk: 1590/22/428 vs 338/10/97
# police.scanner.radio.broadcastify.citizen.apk
# 1(-127/6/46) police.scanner.radio.broadcastify.citizen.apk: 396/5/71 vs 269/11/51
# com.labs.merlinbirdid.app.apk
# -1(-542/-1/18) com.labs.merlinbirdid.app.apk: 614/1/133 vs 72/0/19
# com.romwe.apk
# 1(-1714/-75/34) com.romwe.apk: 2290/90/426 vs 576/15/124
# com.bplus.vtpay.apk
# -1(-826/-7/110) com.bplus.vtpay.apk: 1394/16/322 vs 568/9/126
# cn.wps.pdf.fillsign.apk
# 1(232/11/54) cn.wps.pdf.fillsign.apk: 53/0/9 vs 285/11/54
# com.citymobil.apk
# com.simplepractice.video.apk
# -1(-372/-1/0) com.simplepractice.video.apk: 374/1/46 vs 2/0/1
# kr.co.smartstudy.dinoworld_android_googlemarket.apk
# -1(-201/2/30) kr.co.smartstudy.dinoworld_android_googlemarket.apk: 290/2/44 vs 89/4/32
# com.aol.mobile.aolapp.apk
# -1(-459/8/123) com.aol.mobile.aolapp.apk: 1058/10/224 vs 599/18/133
# com.affinityapps.blk.apk
# 1(-271/13/42) com.affinityapps.blk.apk: 380/1/60 vs 109/14/43
# app.quiktrip.com.quiktrip.apk
# -1(-550/11/60) app.quiktrip.com.quiktrip.apk: 820/2/138 vs 270/13/62
# com.sendo.apk
# -1(-1153/-2/84) com.sendo.apk: 1583/16/362 vs 430/14/100
# ir.nasim.apk
# -1(-256/11/16) ir.nasim.apk: 332/2/32 vs 76/13/18
